# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
# %config InlineBackend.figure_format = 'retina'

import os
import re
import warnings
warnings.filterwarnings('ignore')

# %%
pokemon = pd.read_csv('C:\\Users\\Lee\\Desktop\\GIt\\AIFFEL_first\\FUNDAMENTALS\\pokemon\\pokemon.csv')

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
print(pokemon.shape)
pokemon.info()
# Out:
# (800, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
legendary = pokemon[pokemon.Legendary==True].reset_index(drop=True)
ordinary = pokemon[pokemon.Legendary==False].reset_index(drop=True)

# %%
legendary
# Out:
#       #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0   144             Articuno       Ice    Flying    580   90      85      100
# 1   145               Zapdos  Electric    Flying    580   90      90       85
# 2   146              Moltres      Fire    Flying    580   90     100       90
# 3   150               Mewtwo   Psychic       NaN    680  106     110       90
# 4   150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..  ...                  ...       ...       ...    ...  ...     ...      ...
# 60  719              Diancie      Rock     Fairy    600   50     100      150
# 61  719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 62  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 63  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 64  721            Volcanion      Fire     Water    600   80     110      120
#
# ...

# %%
ordinary
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison    318  45      49       49
# 1      2                Ivysaur   Grass  Poison    405  60      62       63
# 2      3               Venusaur   Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4      4             Charmander    Fire     NaN    309  39      52       43
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 730  711    GourgeistSuper Size   Ghost   Grass    494  85     100      122
# 731  712               Bergmite     Ice     NaN    304  55      69       85
# 732  713                Avalugg     Ice     NaN    514  95     117      184
# 733  714                 Noibat  Flying  Dragon    245  40      30       35
# 734  715                Noivern  Flying  Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # EDA

# %%
pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# - \# :포켓몬 Id number. 성별이 다르지만 같은 포켓몬인 경우 등은 같은 #값을 가진다. int
# - Name : 포켓몬 이름. 포켓몬 각각의 이름으로 저장되고, 800개의 포켓몬의 이름 데이터는 모두 다르다. (unique) str
# - Type 1 : 첫 번째 속성. 속성을 하나만 가지는 경우 Type 1에 입력된다. str
# - Type 2 : 두 번째 속성. 속성을 하나만 가지는 포켓몬의 경우 Type 2는 NaN(결측값)을 가진다. str
# - Total : 전체 6가지 스탯의 총합. int
# - HP : 포켓몬의 체력. int
# - Attack : 물리 공격력. (scratch, punch 등) int
# - Defense : 물리 공격에 대한 방어력. int
# - Sp. Atk : 특수 공격력. (fire blast, bubble beam 등) int
# - Sp. Def : 특수 공격에 대한 방어력. int
# - Speed : 포켓몬 매치에 대해 어떤 포켓몬이 먼저 공격할지를 결정. (더 높은 포켓몬이 먼저 공격한다) int
# - Generation : 포켓몬의 세대. 현재 데이터에는 6세대까지 있다. int
# - Legendary : 전설의 포켓몬 여부. !! Target feature !! bool

# %%
pokemon[pokemon[['#']].duplicated()]['#'].values
# Out:
# array([  3,   6,   6,   9,  15,  18,  65,  80,  94, 115, 127, 130, 142,
#        150, 150, 181, 208, 212, 214, 229, 248, 254, 257, 260, 282, 302,
#        303, 306, 308, 310, 319, 323, 334, 354, 359, 362, 373, 376, 380,
#        381, 382, 383, 384, 386, 386, 386, 413, 413, 428, 445, 448, 460,
#        475, 479, 479, 479, 479, 479, 487, 492, 531, 555, 641, 642, 645,
#        646, 646, 647, 648, 678, 681, 710, 710, 710, 711, 711, 711, 719,
#        720], dtype=int64)

# %%
pokemon[['#']].drop_duplicates()
# Out:
#        #
# 0      1
# 1      2
# 2      3
# 4      4
# 5      5
# ..   ...
# 793  717
# 794  718
# 795  719
# 797  720
# 799  721
#
# [721 rows x 1 columns]

# %% [markdown]
# ## Type

# %%
print(pokemon['Type 1'].nunique(),pokemon['Type 2'].nunique())
print(len(list(set(pokemon['Type 1']))),len(list(set(pokemon['Type 2'])))) # len은 nan까지 count
# Out:
# 18 18
# 18 19

# %%
set(pokemon["Type 2"]) - set(pokemon["Type 1"])
# Out:
# {nan}

# %%
pokemon['Type 2'].isna().sum()
# Out:
# 386

# %%
f , ax = plt.subplots(2,1,figsize=(18,10))

sns.countplot(data=ordinary,x='Type 2',ax=ax[0]).set_title('ordinary')
sns.countplot(data=legendary,x='Type 2',ax=ax[1]).set_title('Legendary')
# Out:
# Text(0.5, 1.0, 'Legendary')

# %%
legendary[legendary['Type 2'] =='Flying']
# Out:
#       #                      Name    Type 1  Type 2  Total   HP  Attack  \
# 0   144                  Articuno       Ice  Flying    580   90      85
# 1   145                    Zapdos  Electric  Flying    580   90      90
# 2   146                   Moltres      Fire  Flying    580   90     100
# 9   249                     Lugia   Psychic  Flying    680  106      90
# 10  250                     Ho-oh      Fire  Flying    680  106     130
# 22  384                  Rayquaza    Dragon  Flying    680  105     150
# 23  384     RayquazaMega Rayquaza    Dragon  Flying    780  105     180
# 40  492          ShayminSky Forme     Grass  Flying    600  100     103
# 48  642  ThundurusIncarnate Forme  Electric  Flying    580   79     115
# 49  642    ThundurusTherian Forme  Electric  Flying    580   79     105
# 52  645   LandorusIncarnate Forme    Ground  Flying    600   89     125
# 53  645     LandorusTherian Forme    Ground  Flying    600   89     145
# ...

# %%
pd.pivot_table(pokemon, index="Type 1", values="Legendary").sort_values(by=["Legendary"], ascending=False)
 # 각 type별 전설포켓몬 비율
# Out:
#           Legendary
# Type 1
# Flying     0.500000
# Dragon     0.375000
# Psychic    0.245614
# Steel      0.148148
# Ground     0.125000
# Fire       0.096154
# Electric   0.090909
# Rock       0.090909
# Ice        0.083333
# Dark       0.064516
# Ghost      0.062500
# Fairy      0.058824
# Grass      0.042857
# Water      0.035714
# Normal     0.020408
# Poison     0.000000
# Fighting   0.000000
# Bug        0.000000

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
plt.figure(figsize=(12, 10))  # 화면 해상도에 따라 그래프 크기를 조정해 주세요.

plt.subplot(211)
sns.countplot(data=ordinary, x="Type 2").set_xlabel('')
plt.title("[Ordinary Pokemons]")

plt.subplot(212)
sns.countplot(data=legendary, x="Type 2", order=pokemon['Type 1'].unique()).set_xlabel('')
plt.title("[Legendary Pokemons]")

plt.show()

# %% [markdown]
# ### Total

# %%
stats = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(data=pokemon , x ='Type 1',y = 'Total',hue = 'Legendary')
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Total'>

# %% [markdown]
# - 전설포켓몬 전체적 스텟이 높다

# %%
figure, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2)
figure.set_size_inches(12, 18)  # 화면 해상도에 따라 그래프 크기를 조정해 주세요.

sns.scatterplot(data=pokemon, y="Total", x="HP", hue="Legendary", ax=ax1)
sns.scatterplot(data=pokemon, y="Total", x="Attack", hue="Legendary", ax=ax2)
sns.scatterplot(data=pokemon, y="Total", x="Defense", hue="Legendary", ax=ax3)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Atk", hue="Legendary", ax=ax4)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Def", hue="Legendary", ax=ax5)
sns.scatterplot(data=pokemon, y="Total", x="Speed", hue="Legendary", ax=ax6)
plt.show()

# %%
sns.scatterplot(data=legendary , x = 'Total',y = 'Type 1')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Type 1'>

# %%
legendary.Total.unique()
# Out:
# array([580, 680, 780, 600, 700, 670, 770, 720, 660], dtype=int64)

# %% [markdown]
# ### Generation

# %%
plt.figure(figsize=(10,8))
plt.subplot(211)
sns.countplot(data = pokemon , x ='Generation').set_title('ALL')
plt.subplot(212)
sns.countplot(data = legendary , x ='Generation').set_title('legendary')
# Out:
# Text(0.5, 1.0, 'legendary')

# %% [markdown]
# ### Name

# %%
pokemon.Name.nunique()
# Out:
# 800

# %%
legendary['Name_len']=legendary['Name'].apply(lambda x :len(x))
ordinary['Name_len']=ordinary['Name'].apply(lambda x :len(x))

# %%
legendary
# Out:
#       #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0   144             Articuno       Ice    Flying    580   90      85      100
# 1   145               Zapdos  Electric    Flying    580   90      90       85
# 2   146              Moltres      Fire    Flying    580   90     100       90
# 3   150               Mewtwo   Psychic       NaN    680  106     110       90
# 4   150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..  ...                  ...       ...       ...    ...  ...     ...      ...
# 60  719              Diancie      Rock     Fairy    600   50     100      150
# 61  719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 62  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 63  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 64  721            Volcanion      Fire     Water    600   80     110      120
#
# ...

# %%
ordinary
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison    318  45      49       49
# 1      2                Ivysaur   Grass  Poison    405  60      62       63
# 2      3               Venusaur   Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4      4             Charmander    Fire     NaN    309  39      52       43
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 730  711    GourgeistSuper Size   Ghost   Grass    494  85     100      122
# 731  712               Bergmite     Ice     NaN    304  55      69       85
# 732  713                Avalugg     Ice     NaN    514  95     117      184
# 733  714                 Noibat  Flying  Dragon    245  40      30       35
# 734  715                Noivern  Flying  Dragon    535  85      70       80
#
# ...

# %%
plt.figure(figsize=(18,10))
plt.subplot(211)
sns.countplot(data=ordinary,x='Name_len').set_title('ordinary')

plt.subplot(212)
sns.countplot(data=legendary,x='Name_len').set_title('ordinary')
# Out:
# Text(0.5, 1.0, 'ordinary')

# %%
len(legendary[legendary.Name_len>=16])
# Out:
# 27

# %%
len(ordinary[ordinary.Name_len>=16])
# Out:
# 61

# %%
pokemon['Name_len'] = pokemon.Name.apply(lambda x :len(x))

# %%
pokemon['Name_long'] = pokemon.Name_len.apply(lambda x: x>=16)

# %%
pokemon['Name']=pokemon['Name'].str.replace(' ','')

# %%
pokemon['Name_isalpha']=pokemon.Name.apply(lambda x: x.isalpha())

# %%
pokemon[pokemon.Name_isalpha == False][['Name']]
# Out:
#                 Name
# 34          Nidoran♀
# 37          Nidoran♂
# 90        Farfetch'd
# 131          Mr.Mime
# 252         Porygon2
# 270            Ho-oh
# 487          MimeJr.
# 525        Porygon-Z
# 794  Zygarde50%Forme

# %%
pokemon = pokemon.replace(to_replace="Nidoran♀", value="Nidoran X")
pokemon = pokemon.replace(to_replace="Nidoran♂", value="Nidoran Y")
pokemon = pokemon.replace(to_replace="Farfetch'd", value="Farfetchd")
pokemon = pokemon.replace(to_replace="Mr.Mime", value="Mr Mime")
pokemon = pokemon.replace(to_replace="Porygon2", value="Porygon")
pokemon = pokemon.replace(to_replace="Ho-oh", value="Ho Oh")
pokemon = pokemon.replace(to_replace="MimeJr.", value="Mime Jr")
pokemon = pokemon.replace(to_replace="Porygon-Z", value="Porygon Z")
pokemon = pokemon.replace(to_replace="Zygarde50%Forme", value="Zygarde Forme")

pokemon.loc[[34, 37, 90, 131, 252, 270, 487, 525, 794]]
# Out:
#        #           Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29      Nidoran X   Poison     NaN    275   55      47       52
# 37    32      Nidoran Y   Poison     NaN    273   46      57       40
# 90    83      Farfetchd   Normal  Flying    352   52      65       55
# 131  122        Mr Mime  Psychic   Fairy    460   40      45       65
# 252  233        Porygon   Normal     NaN    515   85      80       90
# 270  250          Ho Oh     Fire  Flying    680  106     130       90
# 487  439        Mime Jr  Psychic   Fairy    310   20      25       45
# 525  474      Porygon Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Name_len  Name_long  \
# 34        40       40     41           1      False         8      False
# 37        40       40     50           1      False         8      False
# ...

# %%
pokemon['Name']=pokemon['Name'].str.replace(' ','')
pokemon['Name_isalpha']=pokemon.Name.apply(lambda x: x.isalpha())
pokemon[pokemon["Name_isalpha"] == False]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, Name_len, Name_long, Name_isalpha]
# Index: []

# %%
types = pokemon['Type 1'].unique()

# %%
for t in types:
    pokemon[t] = (pokemon["Type 1"] == t) | (pokemon["Type 2"] == t)

# %%
#pokemon[[["Type 1", "Type 2"] + types][0]].head()

# %%
pokemon
# Out:
#        #                  Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1             Bulbasaur    Grass  Poison    318  45      49       49
# 1      2               Ivysaur    Grass  Poison    405  60      62       63
# 2      3              Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMegaVenusaur    Grass  Poison    625  80     100      123
# 4      4            Charmander     Fire     NaN    309  39      52       43
# ..   ...                   ...      ...     ...    ...  ..     ...      ...
# 795  719               Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMegaDiancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopaConfined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopaUnbound  Psychic    Dark    680  80     160       60
# 799  721             Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Model

# %%
original=pd.read_csv('C:\\Users\\Lee\\Desktop\\GIt\\AIFFEL_first\\FUNDAMENTALS\\pokemon\\pokemon.csv')

# %%
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']

# %%
target = 'Legendary'

# %%
X = original[features]
y = original[target]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=25)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_matrix(y_test, y_pred)
# Out:
# array([[144,   3],
#        [  5,   8]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.97       147
#         True       0.73      0.62      0.67        13
#
#     accuracy                           0.95       160
#    macro avg       0.85      0.80      0.82       160
# weighted avg       0.95      0.95      0.95       160

# %% [markdown]
# ### Upgrade

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Name_len',
#        'Name_long', 'Name_isalpha', 'Grass', 'Fire', 'Water', 'Bug', 'Normal',
#        'Poison', 'Electric', 'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock',
#        'Ghost', 'Ice', 'Dragon', 'Dark', 'Steel', 'Flying'],
#       dtype='object')

# %%
feature = ['Total', 'HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed', 'Generation',  'Name_len',
       'Name_long',  'Grass', 'Fire', 'Water', 'Bug', 'Normal',
       'Poison', 'Electric', 'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock',
       'Ghost', 'Ice', 'Dragon', 'Dark', 'Steel', 'Flying']

# %%
len(feature)
# Out:
# 28

# %%
X = pokemon[feature]
y = pokemon['Legendary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# %%
model = DecisionTreeClassifier(random_state=25)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[142,   5],
#        [  2,  11]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       147
#         True       0.69      0.85      0.76        13
#
#     accuracy                           0.96       160
#    macro avg       0.84      0.91      0.87       160
# weighted avg       0.96      0.96      0.96       160
