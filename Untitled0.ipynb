# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/AIFFEL/.git/

# %%
# !git config --global user.email wodms7933@gamil.com
# !git config --global user.name wodms79331
